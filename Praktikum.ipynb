# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-448b3b54-6d57-49d7-a5ef-af5850508314" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-448b3b54-6d57-49d7-a5ef-af5850508314">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving jumlah-peserta-keluarga-berencana-baru-menurut-bulan-dan-sarana-penanganan-di-provinsi-dki-jakarta-2020.csv to jumlah-peserta-keluarga-berencana-baru-menurut-bulan-dan-sarana-penanganan-di-provinsi-dki-jakarta-2020.csv

# %%
import os
import pandas as pd
from pathlib import Path
import seaborn

cwd = os.getcwd()
kb = pd.read_csv('jumlah-peserta-keluarga-berencana-baru-menurut-bulan-dan-sarana-penanganan-di-provinsi-dki-jakarta-2020.csv')
print(kb)
# Out:
#     tahun  bulan jenis_sarana_penanganan  jumlah
# 0    2020      1               RS/RB/KKB    6914
# 1    2020      1          Dr./Bdn Swasta    5584
# 2    2020      2               RS/RB/KKB    6646
# 3    2020      2          Dr./Bdn Swasta    6482
# 4    2020      3               RS/RB/KKB    5728
# 5    2020      3          Dr./Bdn Swasta    5140
# 6    2020      4               RS/RB/KKB    4237
# 7    2020      4          Dr./Bdn Swasta    4202
# 8    2020      5               RS/RB/KKB    3960
# 9    2020      5          Dr./Bdn Swasta    3919
# 10   2020      6               RS/RB/KKB   10915
# 11   2020      6          Dr./Bdn Swasta    4522
# 12   2020      7               RS/RB/KKB    6763
# 13   2020      7          Dr./Bdn Swasta    4086
# 14   2020      8               RS/RB/KKB    6207
# 15   2020      8          Dr./Bdn Swasta    3832
# 16   2020      9               RS/RB/KKB    6482
# 17   2020      9          Dr./Bdn Swasta    3831
# ...

# %%
diagram = seaborn.histplot(kb)
print(kb)
# Out:
#     tahun  bulan jenis_sarana_penanganan  jumlah
# 0    2020      1               RS/RB/KKB    6914
# 1    2020      1          Dr./Bdn Swasta    5584
# 2    2020      2               RS/RB/KKB    6646
# 3    2020      2          Dr./Bdn Swasta    6482
# 4    2020      3               RS/RB/KKB    5728
# 5    2020      3          Dr./Bdn Swasta    5140
# 6    2020      4               RS/RB/KKB    4237
# 7    2020      4          Dr./Bdn Swasta    4202
# 8    2020      5               RS/RB/KKB    3960
# 9    2020      5          Dr./Bdn Swasta    3919
# 10   2020      6               RS/RB/KKB   10915
# 11   2020      6          Dr./Bdn Swasta    4522
# 12   2020      7               RS/RB/KKB    6763
# 13   2020      7          Dr./Bdn Swasta    4086
# 14   2020      8               RS/RB/KKB    6207
# 15   2020      8          Dr./Bdn Swasta    3832
# 16   2020      9               RS/RB/KKB    6482
# 17   2020      9          Dr./Bdn Swasta    3831
# ...

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('jumlah-peserta-keluarga-berencana-baru-menurut-bulan-dan-sarana-penanganan-di-provinsi-dki-jakarta-2020.csv')
bar = data.iloc[:,1]

mean = np.mean(bar)
median = np.median(bar)

print('Hasil Mean   = ',mean)
print('Hasil Median = ',median)
# Out:
# Hasil Mean   =  6.5
# Hasil Median =  6.5

# %%
import statistics
print('Jumlah Mean Keluarga Berencana :')
statistics.mean(kb['jumlah'])
# Out:
# Jumlah Mean Keluarga Berencana :
# 5370.166666666667

# %%
import statistics
print('Jumlah Median Keluarga Berencana :')
statistics.median(kb['jumlah'])
# Out:
# Jumlah Median Keluarga Berencana :
# 5362.0

# %%
print(seaborn.histplot(kb['jumlah']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import statistics
print('Jumlah Mean Tahun KB :')
statistics.mean(kb['tahun'])
# Out:
# Jumlah Mean Tahun KB :
# 2020

# %%
import statistics
print('Jumlah Median Tahun KB :')
statistics.median(kb['tahun'])
# Out:
# Jumlah Median Tahun KB :
# 2020.0

# %%
print(seaborn.histplot(kb['tahun']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
import statistics
print('Jumlah Mean Bulan KB :')
statistics.mean(kb['bulan'])
# Out:
# Jumlah Mean Bulan KB :
# 6.5

# %%
import statistics
print('Jumlah Median Bulan KB :')
statistics.median(kb['bulan'])
# Out:
# Jumlah Median Bulan KB :
# 6.5

# %%
print(seaborn.histplot(kb['bulan']))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
